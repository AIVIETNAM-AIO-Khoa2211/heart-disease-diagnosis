# %% [markdown]
# ## Setup - Import library and function

# %%
import sys
from pathlib import Path

# Add root project's folder (parent of notebooks/) into sys.path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.data_loader import load_dataset
from src.preprocessing import to_num
from src.visualization import heatmap, inspect_categorical_columns, plot_categorical_pie_charts, plot_numeric_histograms
import src.config as config

# %% [markdown]
# ## Read and preprocess numeric data

# %%
df = load_dataset(config.CLEVELAND_CSV_PATH)
df = to_num(df, config.NUMERIC_COLS, config.TARGET_COL)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB
# None

# %%
#display heatmap to check correlation 
heatmap(df,config.NUMERIC_COLS)

# %%
inspect_categorical_columns(df, config.CATEGORICAL_COLS)
# Out:
# ...
# Column: sex
# Dtype: int64
# Number of unique values: 2
# Unique values:
#   - np.int64(1): 205 samples
#   - np.int64(0): 97 samples
#
# ...
# Column: cp
# Dtype: int64
# Number of unique values: 4
# Unique values:
#   - np.int64(3): 144 samples
#   - np.int64(2): 86 samples
#   - np.int64(1): 50 samples
#   - np.int64(0): 22 samples
#
# ...
# Column: fbs
# Dtype: int64
# Number of unique values: 2
# Unique values:
#   - np.int64(0): 258 samples
#   - np.int64(1): 44 samples
#
# ...
# Column: restecg
# Dtype: int64
# Number of unique values: 3
# Unique values:
#   - np.int64(2): 147 samples
#   - np.int64(0): 151 samples
#   - np.int64(1): 4 samples
#
# ...
# Column: exang
# Dtype: int64
# Number of unique values: 2
# Unique values:
#   - np.int64(1): 99 samples
#   - np.int64(0): 203 samples
#
# ...
# Column: slope
# Dtype: int64
# Number of unique values: 3
# Unique values:
#   - np.int64(1): 140 samples
#   - np.int64(2): 20 samples
#   - np.int64(0): 142 samples
#
# ...
# Column: ca
# Dtype: int64
# ...

# %%
plot_categorical_pie_charts(df,cate_cols=config.CATEGORICAL_COLS)
plot_numeric_histograms(df, num_cols=config.NUMERIC_COLS)
